# %% [markdown]
# **Name**:- Nimit Kumar
#
# **PRN**:- 20070122087
#
# **Batch**:- CSB1

# %% [markdown]
# **Aim**:-rite a python program to implement Depth First Search Traversal

# %% [markdown]
# **Algorithm**:-
#
# 1.   Start program
# 2.   Import defaultdict from collections
# 3.   Declare a class graph and in it define 2 functions addedge and Dfstil for adding a edge and to check if the edge is visited or not respectively
# 4.   Add the graph edges
# 5.   Call the class
# 6.   End the program

# %%
from collections import defaultdict

class graph:
  def __init__(self):
    self.graph = defaultdict(list)
  
  def addEdge(self,u,v):
    self.graph[u].append(v)
  def DFSUtil(self, v, visited):
    visited[v]= True
    print (v),
 
    for i in self.graph[v]:
      if visited[i] == False:
        self.DFSUtil(i, visited)
 
 
  def DFS(self):
    V = len(self.graph)  #total vertices
 
    visited =[False]*(V)
 
    for i in range(V):
      if visited[i] == False:
        self.DFSUtil(i, visited)

g = graph()
g.addEdge(1, 0)
g.addEdge(1, 2)
g.addEdge(0, 2)
g.addEdge(2, 1)
g.addEdge(2, 3)
g.addEdge(3, 3)
print ("Following is Depth First Traversal")
g.DFS()
# Out:
# Following is Depth First Traversal
# 0
# 2
# 1
# 3

# %% [markdown]
# **Learning Outcomes**:- Learnt how to implement DFS on a graph in Python
